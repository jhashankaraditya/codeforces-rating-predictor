# %%
import pandas as pd
import numpy as np

# %%
ratings=pd.read_csv('cleaned_regression_df.csv')

# %%
X=ratings.drop(columns='rating')
y=ratings['rating']

# %%
X
# Out:
#       Unnamed: 0  contest1  contest2  contest3  contest4  contest5  contest6  \
# 0              0      2078      2055      2115      2047      2024      2010
# 1              1      2194      2114      2152      2179      2211      2154
# 2              2      2120      2206      2147      2234      2294      2090
# 3              3      2224      2222      2166      2116      2029      2113
# 4              4      2128      2120      2072      2018      1963      2039
# ...          ...       ...       ...       ...       ...       ...       ...
# 1231        1231      2226      2274      2098      2008      2102      2146
# 1232        1232      2756      2712      2719      2770      2683      2674
# 1233        1233      2077      2100      2109      2115      2167      2145
# 1234        1234      2000      1951      1900      1927      1820      1787
# 1235        1235      1977      1910      1974      1823      1796      1790
#
# ...

# %%
y
# Out:
# 0       2115
# 1       2254
# 2       2344
# 3       2224
# 4       2128
#         ...
# 1231    2319
# 1232    2770
# 1233    2167
# 1234    2000
# 1235    1977
# Name: rating, Length: 1236, dtype: int64

# %%
X.drop(columns=['Unnamed: 0'],inplace=True)
X
# Out:
#       contest1  contest2  contest3  contest4  contest5  contest6  contest7  \
# 0         2078      2055      2115      2047      2024      2010      1953
# 1         2194      2114      2152      2179      2211      2154      2170
# 2         2120      2206      2147      2234      2294      2090      2089
# 3         2224      2222      2166      2116      2029      2113      2104
# 4         2128      2120      2072      2018      1963      2039      1932
# ...        ...       ...       ...       ...       ...       ...       ...
# 1231      2226      2274      2098      2008      2102      2146      2185
# 1232      2756      2712      2719      2770      2683      2674      2637
# 1233      2077      2100      2109      2115      2167      2145      2147
# 1234      2000      1951      1900      1927      1820      1787      1721
# 1235      1977      1910      1974      1823      1796      1790      1829
#
#       contest8  contest9  contest10
# ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import r2_score

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr=lr.predict(X_test)

# %%
r2_score(y_test,y_pred_lr)
# Out:
# 0.9198127685639399

# %%
from sklearn.model_selection import cross_val_score
scores = cross_val_score(lr, X, y, cv=5, scoring='r2')
print("Cross-validation scores:", scores)
print("Mean cross-validation score:", np.mean(scores))
# Out:
# Cross-validation scores: [0.89908616 0.94221757 0.89258179 0.94313265 0.92735672]
# Mean cross-validation score: 0.9208749760561961

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 10, 20, 30],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': ['auto', 'sqrt', 'log2']
}

# %%
rf_gs = RandomForestRegressor(random_state=42)

# %%
grid_search = GridSearchCV(estimator=rf_gs, param_grid=param_grid, cv=5, scoring='r2', n_jobs=-1)

# %%
grid_search.fit(X_train, y_train)
# Out:
# C:\Users\Aditya Shankar Jha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 540 fits failed out of a total of 1620.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 188 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Aditya Shankar Jha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Aditya Shankar Jha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
# ...

# %%
best_params = grid_search.best_params_
best_score = grid_search.best_score_

# %%
print("Best Parameters:", best_params)
print("Best R^2 Score:", best_score)
# Out:
# Best Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}
# Best R^2 Score: 0.944986747875617

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint
param_dist = {
    'n_estimators': randint(100, 500),
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': randint(2, 11),
    'min_samples_leaf': randint(1, 5),
    'max_features': ['auto', 'sqrt', 'log2']
}

# %%
rf_rs = RandomForestRegressor(random_state=42)

# %%
random_search = RandomizedSearchCV(estimator=rf_rs, param_distributions=param_dist, n_iter=100, cv=5, scoring='r2', n_jobs=-1, random_state=42)

# %%
random_search.fit(X_train, y_train)
# Out:
# C:\Users\Aditya Shankar Jha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 165 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 54 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\Aditya Shankar Jha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Aditya Shankar Jha\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1466, in wrapper
#     estimator._validate_params()
# ...

# %%
best_params = random_search.best_params_
best_score = random_search.best_score_

# %%
print("Best Parameters:", best_params)
print("Best R^2 Score:", best_score)
# Out:
# Best Parameters: {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 3, 'n_estimators': 443}
# Best R^2 Score: 0.9456284663632101

# %%
from sklearn.svm import SVR
svm_regressor1 = SVR(kernel='linear')
svm_regressor2 = SVR(kernel='rbf')

# %%
svm_regressor1.fit(X_train, y_train)
svm_regressor2.fit(X_train, y_train)
# Out:
# SVR()

# %%
y_pred1 = svm_regressor1.predict(X_test)
y_pred2 = svm_regressor2.predict(X_test)

# %%
linear_r2 = r2_score(y_test, y_pred1)
rbf_r2 = r2_score(y_test, y_pred2)
print("R^2 Score Linear:", linear_r2)
print("R^2 Score RBF:", rbf_r2)
# Out:
# R^2 Score Linear: 0.915762891757047
# R^2 Score RBF: 0.438768227795999
